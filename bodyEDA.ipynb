# %%
import pandas as pd
female_file = "female.csv"
male_file = "male.csv"

# %%
female_data = pd.read_csv(female_file)
male_data = pd.read_csv(male_file)

# %%
male_data.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
male_data.tail()
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 4077      29442                             235            1353
# 4078      29443                             247            1473
# 4079      29447                             264            1394
# 4080      29451                             203            1417
# 4081      29452                             327            1523
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 4077                    312                 216          1263
# 4078                    336                 234          1346
# 4079                    313                 227          1280
# 4080                    327                 223          1314
# 4081                    358                 226          1408
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 4077                      228               193                384
# 4078                      253               196                428
# ...

# %%
male_data.describe()
# Out:
#           subjectid  abdominalextensiondepthsitting  acromialheight  \
# count   4082.000000                     4082.000000     4082.000000
# mean   20003.370897                      254.650906     1440.736894
# std     6568.435122                       37.327178       63.287242
# min    10027.000000                      163.000000     1194.000000
# 25%    14270.250000                      227.000000     1398.000000
# 50%    17236.500000                      251.000000     1439.000000
# 75%    27315.750000                      279.000000     1481.000000
# max    29452.000000                      451.000000     1683.000000
#
#        acromionradialelength  anklecircumference  axillaheight  \
# count            4082.000000         4082.000000   4082.000000
# mean              335.244488          229.343949   1329.082068
# std                17.482795           14.649102     59.516123
# min               270.000000          156.000000   1106.000000
# ...

# %%
female_data.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# ...

# %%
female_data.tail()
# Out:
#       SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 1981      29501                             285            1392
# 1982      29502                             262            1324
# 1983      29503                             260            1334
# 1984      29511                             205            1293
# 1985     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 1981                    335                 223          1297
# 1982                    301                 202          1204
# 1983                    318                 213          1259
# 1984                    302                 199          1207
# 1985                    308                 210          1256
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 1981                      252               196                368
# 1982                      236               181                378
# ...

# %%
female_data.describe()
# Out:
#            SubjectId  abdominalextensiondepthsitting  acromialheight  \
# count    1986.000000                     1986.000000     1986.000000
# mean    22306.606244                      229.651057     1335.095166
# std     20904.730297                       31.464691       58.079885
# min     10037.000000                      155.000000     1115.000000
# 25%     17667.000000                      207.000000     1298.000000
# 50%     22096.500000                      227.000000     1332.000000
# 75%     26089.750000                      249.000000     1374.000000
# max    920103.000000                      358.000000     1536.000000
#
#        acromionradialelength  anklecircumference  axillaheight  \
# count            1986.000000         1986.000000   1986.000000
# mean              311.198389          215.739678   1239.029708
# std                17.164691           14.891757     55.801958
# min               249.000000          170.000000   1038.000000
# ...

# %%
print([x for x in male_data.columns])
# Out:
# ['subjectid', 'abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth', 'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength', 'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth', 'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion', 'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength', 'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth', 'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference', 'handlength', 'headbreadth', 'headcircumference', 'headlength', 'he
# ...

# %%
print([x for x in female_data.columns])
# Out:
# ['SubjectId', 'abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth', 'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength', 'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth', 'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion', 'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength', 'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth', 'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference', 'handlength', 'headbreadth', 'headcircumference', 'headlength', 'he
# ...

# %%
def div_conversion(df, column, div):
    return df[column].apply(lambda x: x/div)

# %%
male_data['stature'] = div_conversion(male_data, 'stature', 1000) # Convert to Meters
male_data['weightkg'] = div_conversion(male_data, 'weightkg', 10) # Convert to Kg
male_data['chestcircumference'] = div_conversion(male_data, 'chestcircumference', 10) # convert to cm 
male_data['waistcircumference'] = div_conversion(male_data, 'waistcircumference', 10) #convert to cm
female_data['stature'] = div_conversion(female_data, 'stature', 1000) # Convert to Meters
female_data['weightkg'] = div_conversion(female_data, 'weightkg', 10) # Convert to Kg
female_data['chestcircumference'] = div_conversion(female_data, 'chestcircumference', 10) # convert to cm 
female_data['waistcircumference'] = div_conversion(female_data, 'waistcircumference', 10) #convert to cm

# %%
print(male_data['stature'].describe(),any(male_data['stature'].isnull()))
print(male_data['weightkg'].describe(),any(male_data['weightkg'].isnull()))
print(male_data['chestcircumference'].describe(),any(male_data['chestcircumference'].isnull()))
print(male_data['waistcircumference'].describe(),any(male_data['waistcircumference'].isnull()))

print(female_data['stature'].describe(),any(female_data['stature'].isnull()))
print(female_data['weightkg'].describe(),any(female_data['weightkg'].isnull()))
print(female_data['chestcircumference'].describe(),any(female_data['chestcircumference'].isnull()))
print(female_data['waistcircumference'].describe(),any(female_data['waistcircumference'].isnull()))
# Out:
# count    4082.000000
# mean        1.756215
# std         0.068551
# min         1.491000
# 25%         1.710000
# 50%         1.755000
# 75%         1.802000
# max         1.993000
# Name: stature, dtype: float64 False
# count    4082.000000
# mean       85.523959
# std        14.220699
# min        39.300000
# 25%        75.600000
# 50%        84.600000
# 75%        94.400000
# max       144.200000
# Name: weightkg, dtype: float64 False
# count    4082.000000
# mean      105.870554
# std         8.743527
# min        77.400000
# 25%        99.600000
# 50%       105.600000
# 75%       111.700000
# max       146.900000
# Name: chestcircumference, dtype: float64 False
# count    4082.000000
# mean       94.057741
# std        11.170587
# min        64.800000
# 25%        85.700000
# 50%        93.700000
# 75%       101.600000
# max       137.900000
# Name: waistcircumference, dtype: float64 False
# count    1986.000000
# mean        1.628473
# std         0.064200
# ...

# %%
#which parameters are of use: stature, weightkg divide by 10 because americans....., chestcircumference, waistcircumference, waistdepth
def create_sample(df, gender, columns: list, sample_size):
        [list(df.columns).index(column) for column in columns]
        df = df.iloc[:sample_size, [list(df.columns).index(column) for column in columns]].copy()
        df.to_csv(f'{gender}_sample{sample_size}.csv', index=False)

def backup_sample(df, gender, sample_size):
    df.to_csv(f'{gender}_sample{sample_size}.csv', index=False)

# %%
create_sample(male_data, 'male', ['chestcircumference', 'waistcircumference'], 100)
create_sample(female_data, 'female', ['chestcircumference', 'waistcircumference'], 100)

# %%
df = pd.read_csv('male_sample100.csv')
ff = pd.read_csv('female_sample100.csv')

# %%
df.head()
# Out:
#    chestcircumference  waistcircumference
# 0               107.4                93.3
# 1               102.1                87.0
# 2               112.0                96.4
# 3               111.4                85.7
# 4               104.8                86.8

# %%
ff.head()
# Out:
#    chestcircumference  waistcircumference
# 0                92.2                85.0
# 1                83.9                70.8
# 2                87.4                72.7
# 3               100.8                92.3
# 4               108.9               116.3

# %% [markdown]
# Male T-shirt Size Chart by Body Measurement, <br>
# CM: SIZE WAIST CHEST <br>
# XXS 69-74 cm 74-79 cm <br>
# XS 71-76 cm 76-81 cm <br>
# S 76-81 cm 86-91 cm <br>
# M 81-84 cm 97-102 cm <br>
# L 84-87 cm 107-112 cm <br>
# XL 91-97 cm 116-122 cm <br>
# XXL 102-107 cm 122-127 cm <br>
# 3XL 112-122 cm 127-132 cm <br>
#
# Female EU SIZE INT. WAIST CHEST<br>
# XXS 54-57 cm 70-75 cm <br>
# XS 58-66 cm 75-81 cm<br>
# S 67-71 cm 82-87 cm<br>
# M 72-80 cm 89-95 cm<br>
# L 81-92 cm 96-105 cm <br>
# XL 93-101 cm 106-115 cm<br>
# XXL 101-104 cm 116-122 cm

# %% [markdown]
# Chest + waist with correlation between weight + height

# %%
men_sizes = {"XXS": [(69, 71), (74, 76)], "XS": [(71, 77), (76, 86)], "S": [(77, 81), (86, 97)], "M": [(81, 85), (97, 107)], "L": [(85, 92), (107, 116)], "XL": [(92, 102), (116, 122)], "XXL": [(102, 112), (122, 128)], "3XL": [(112, 122), (128, 132)]}
female_sizes = {"XSS": [(54, 58), (70, 75)], "XS": [(58, 67), (75,82)], "S": [(67, 72), (82, 89)], "M": [(72, 81), (89, 96)], "L": [(81, 93), (96, 106)], "XL": [(93, 101), (106, 116)], "XXL": [(101, 104), (116, 122)]}

# %%
def categories_by_size(df, sizes):
    cloth_sizes = ["L"]
    for row in range(df.shape[0]):
        key_found = False
        for key in sizes:
            for i, col in enumerate(df):
                if sizes[key][i][0] <= df[col][row] <= sizes[key][i][1]:
                    cloth_sizes.append(key)
                    key_found = True
                    break

            if key_found: break

    df["clothingsize"] = cloth_sizes
    return df

# %%
categories_by_size(df, men_sizes)
# Out:
#     chestcircumference  waistcircumference clothingsize
# 0                107.4                93.3            L
# 1                102.1                87.0            S
# 2                112.0                96.4            S
# 3                111.4                85.7            S
# 4                104.8                86.8           XS
# ..                 ...                 ...          ...
# 95                99.4                80.9           XS
# 96               100.1                86.2            S
# 97               106.9               102.7            M
# 98                99.5                79.7           XS
# 99               110.4               108.2            L
#
# [100 rows x 3 columns]

# %%
print(df.columns, '\n')
print(df.count())
print(df)
# Out:
# Index(['chestcircumference', 'waistcircumference', 'clothingsize'], dtype='object')
#
# chestcircumference    100
# waistcircumference    100
# clothingsize          100
# dtype: int64
#     chestcircumference  waistcircumference clothingsize
# 0                107.4                93.3            L
# 1                102.1                87.0            S
# 2                112.0                96.4            S
# 3                111.4                85.7            S
# 4                104.8                86.8           XS
# ..                 ...                 ...          ...
# 95                99.4                80.9           XS
# 96               100.1                86.2            S
# 97               106.9               102.7            M
# 98                99.5                79.7           XS
# 99               110.4               108.2            L
#
# [100 rows x 3 columns]

# %%
def k_nearest_neighbor(df, P, k):
    def vec_abs(vec):
        return sqrt(sum([unit**2 for unit in vec]))
    
    def compute_vec(*args):
        dim = 2
        vectors = [[args[index][row] - args[index-1][row] for row in range(dim)] for index in range(1, len(args))]
        vector = [sum([vec[col] for vec in vectors]) for col in range(dim)] if len(vectors) > 1 else vectors[0]
        return zip(args[0], vector) if len(args) > 2 else zip(args[0], args[1])

    x, y = df.columns
    
    return 0
